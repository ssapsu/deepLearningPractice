# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Pandas에는 Series와 DataFrame이라는 데이터 오브젝트가 있다. Series는 1차원 배열, DataFrame은 2차원 배열로 데이터를 담고 있다.

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

print(s)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)

print(dates)

df=pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))

print(df)
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')
#                    A         B         C         D
# 2013-01-01  0.130380 -1.349133 -0.399680  1.068782
# 2013-01-02  0.041171  1.895948 -0.629701 -0.185399
# 2013-01-03 -1.564584 -1.385799 -0.621758  1.263832
# 2013-01-04  2.333913 -2.001332  0.753812  0.262173
# 2013-01-05 -0.982311  0.875003 -1.240287  1.954233
# 2013-01-06 -2.944810 -1.165761 -0.421971  1.338320

# %% [markdown]
# DataFrame을 생성하는 또 다른 방법으로는 여러 종류의 자료들이 담긴 딕셔너리(dict)를 넣어주어 만들 수 있다.

# %%
df2 = pd.DataFrame({'A': 1.,
                    'B': pd.Timestamp('20130102'),
                    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                    'D': np.array([3]*4, dtype='int32'),
                    'E': pd.Categorical(['test', 'train', 'test', 'train']),
                    'F': 'foo'})

print(df2)
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
dir(df2)
# Out:
# ['A',
#  'B',
#  'C',
#  'D',
#  'E',
#  'F',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_accum_func',
#  '_add_numeric_operations',
#  '_agg_by_level',
#  '_agg_examples_doc',
#  '_agg_summary_and_see_also_doc',
#  '_align_frame',
#  '_align_series',
#  '_arith_method',
#  '_as_manager',
#  '_attrs',
#  '_box_col_values',
#  '_can_fast_transpose',
#  '_check_inplace_and_allows_duplicate_labels',
#  '_check_inplace_setting',
#  '_check_is_chained_assignment_possible',
#  '_check_label_or_level_ambiguity',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_clip_with_one_bound',
#  '_clip_with_scalar',
#  '_cmp_method',
#  '_combine_frame',
#  '_consolidate',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_axes_from_arguments',
#  '_construct_result',
#  '_constructor',
#  '_constructor_sliced',
#  '_convert',
#  '_count_level',
#  '_data',
#  '_dir_additions',
#  '_dir_deletions',
#  '_dispatch_frame_op',
#  '_drop_axis',
#  '_drop_labels_or_levels',
#  '_ensure_valid_index',
#  '_find_valid_index',
#  '_flags',
#  '_from_arrays',
#  '_from_mgr',
#  '_get_agg_axis',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cleaned_column_resolvers',
#  '_get_column_array',
#  '_get_index_resolvers',
#  '_get_item_cache',
#  '_get_label_or_level_values',
#  '_get_numeric_data',
#  '_get_value',
#  '_getitem_bool_array',
#  '_getitem_multilevel',
#  '_gotitem',
#  '_hidden_attrs',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_info_repr',
#  '_init_mgr',
#  '_inplace_method',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_copy',
#  '_is_homogeneous_type',
#  '_is_label_or_level_reference',
#  '_is_label_reference',
#  '_is_level_reference',
#  '_is_mixed_type',
#  '_is_view',
#  '_iset_item',
#  '_iset_item_mgr',
#  '_iset_not_inplace',
#  '_item_cache',
#  '_iter_column_arrays',
#  '_ixs',
#  '_join_compat',
#  '_logical_func',
#  '_logical_method',
#  '_maybe_cache_changed',
#  '_maybe_update_cacher',
#  '_metadata',
#  '_mgr',
#  '_min_count_stat_function',
#  '_needs_reindex_multi',
#  '_protect_consolidate',
#  '_reduce',
#  '_reindex_axes',
#  '_reindex_columns',
#  '_reindex_index',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_replace_columnwise',
#  '_repr_data_resource_',
#  '_repr_fits_horizontal_',
#  '_repr_fits_vertical_',
#  '_repr_html_',
#  '_repr_latex_',
#  '_reset_cache',
#  '_reset_cacher',
#  '_sanitize_column',
#  '_series',
#  '_set_axis',
#  '_set_axis_name',
#  '_set_axis_nocheck',
#  '_set_is_copy',
#  '_set_item',
#  '_set_item_frame_value',
#  '_set_item_mgr',
#  '_set_value',
#  '_setitem_array',
#  '_setitem_frame',
#  '_setitem_slice',
#  '_slice',
#  '_stat_axis',
#  '_stat_axis_name',
#  '_stat_axis_number',
#  '_stat_function',
#  '_stat_function_ddof',
#  '_take_with_is_copy',
#  '_to_dict_of_blocks',
#  '_typ',
#  '_update_inplace',
#  '_validate_dtype',
#  '_values',
#  '_where',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'any',
#  'append',
#  'apply',
#  'applymap',
#  'asfreq',
#  'asof',
#  'assign',
#  'astype',
#  'at',
#  'at_time',
#  'attrs',
#  'axes',
#  'backfill',
#  'between_time',
#  'bfill',
#  'bool',
#  'boxplot',
#  'clip',
#  'columns',
#  'combine',
#  'combine_first',
#  'compare',
#  'convert_dtypes',
#  'copy',
#  'corr',
#  'corrwith',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'div',
#  'divide',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'eval',
#  'ewm',
#  'expanding',
#  'explode',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'flags',
#  'floordiv',
#  'from_dict',
#  'from_records',
#  'ge',
#  'get',
#  'groupby',
#  'gt',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'index',
#  'infer_objects',
#  'info',
#  'insert',
#  'interpolate',
#  'isin',
#  'isna',
#  'isnull',
#  'items',
#  'iteritems',
#  'iterrows',
#  'itertuples',
#  'join',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'loc',
#  'lookup',
#  'lt',
#  'mad',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'melt',
#  'memory_usage',
#  'merge',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'ndim',
#  'ne',
#  'nlargest',
#  'notna',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'pad',
#  'pct_change',
#  'pipe',
#  'pivot',
#  'pivot_table',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'quantile',
#  'query',
#  'radd',
#  'rank',
#  'rdiv',
#  'reindex',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'replace',
#  'resample',
#  'reset_index',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'select_dtypes',
#  'sem',
#  'set_axis',
#  'set_flags',
#  'set_index',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'slice_shift',
#  'sort_index',
#  'sort_values',
#  'squeeze',
#  'stack',
#  'std',
#  'style',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_feather',
#  'to_gbq',
#  'to_hdf',
#  'to_html',
#  'to_json',
#  'to_latex',
#  'to_markdown',
#  'to_numpy',
#  'to_parquet',
#  'to_period',
#  'to_pickle',
#  'to_records',
#  'to_sql',
#  'to_stata',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'to_xml',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tz_convert',
#  'tz_localize',
#  'unstack',
#  'update',
#  'value_counts',
#  'values',
#  'var',
#  'where',
#  'xs']

# %%
df2.head()
df2.tail(2)
# Out:
#      A          B    C  D      E    F
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
filepath = "./battery/1585 Ga raw.xlsx"

# %%
DODI_C_20 = pd.read_excel(filepath, sheet_name = 0,engine = "openpyxl", header = None)
PROD_C_20 = pd.read_excel(filepath, sheet_name = 1,engine = "openpyxl", header = None)
DODI_D_20 = pd.read_excel(filepath, sheet_name = 2,engine = "openpyxl", header = None)
PROD_D_20 = pd.read_excel(filepath, sheet_name = 3,engine = "openpyxl", header = None)
DODI_C_rt = pd.read_excel(filepath, sheet_name = 4,engine = "openpyxl", header = None)
PROD_C_rt = pd.read_excel(filepath, sheet_name = 5,engine = "openpyxl", header = None)
DODI_D_rt = pd.read_excel(filepath, sheet_name = 6,engine = "openpyxl", header = None)
PROD_D_rt = pd.read_excel(filepath, sheet_name = 7,engine = "openpyxl", header = None)
DODI_C_60 = pd.read_excel(filepath, sheet_name = 8,engine = "openpyxl", header = None)
PROD_C_60 = pd.read_excel(filepath, sheet_name = 9,engine = "openpyxl", header = None)
DODI_D_60 = pd.read_excel(filepath, sheet_name = 10,engine = "openpyxl", header = None)
PROD_D_60 = pd.read_excel(filepath, sheet_name = 11,engine = "openpyxl", header = None)

batteryList = [
    DODI_C_20, PROD_C_20, DODI_D_20, PROD_D_20, 
    DODI_C_rt, PROD_C_rt, DODI_D_rt, PROD_D_rt,
    DODI_C_60, PROD_C_60, DODI_D_60, PROD_D_60
]

batteryListName = [
    'DODI_C_20', 'PROD_C_20', 'DODI_D_20', 'PROD_D_20', 
    'DODI_C_rt', 'PROD_C_rt', 'DODI_D_rt', 'PROD_D_rt',
    'DODI_C_60', 'PROD_C_60', 'DODI_D_60', 'PROD_D_60'
]

for dataSet in batteryList:
    dataSet.replace('', np.nan, inplace=True)

DODI_C = dict()
DODI_D = dict()
PROD_C = dict()
PROD_D = dict()

batteryType = [DODI_C, DODI_D, PROD_C, PROD_D]

DODI_C=[DODI_C_20, DODI_C_rt, DODI_C_60]
DODI_D=[DODI_D_20,DODI_D_rt,DODI_D_60]
PROD_C=[PROD_C_20,PROD_C_rt,PROD_C_60]
PROD_D=[PROD_D_20,PROD_D_rt,PROD_D_60]

# %%
def printBatteryData():
    count = 1
    plt.figure(figsize=(16,16))
    for dataSet in batteryList:
        plt.subplot(3,4,count)
        plt.title(batteryListName[count-1])
        for i in range(1, (int)(dataSet.shape[1])-1, 2):
            plt.plot(dataSet.iloc[:,[i+1]], dataSet.iloc[:,[i]])
        plt.xlabel('coulomb')
        plt.ylabel('Volatage')
        count += 1

# %% [markdown]
# DataFrame에서 특정 행, 열을 선택하는 법
#
# 컬럼명 또는 행의 Index를 사용하는 방법->DataFrame.loc[] 사용
# [행 정보, 열 정보(리스트로 기입)]
# 열 또는 행의 순서(위치) 사용하는 방법->DataFrame.iloc[] 사용

# %%
printBatteryData()

# %%
def dataParse():
    batterycount = 0
    degreecount = 0
    testcount = 0
    dodi_c = []; dodi_d = []; prod_c = []; prod_d = []
    batteryData = [dodi_c,dodi_d,prod_c,prod_d]

# %%
DODI_C_20.shape[1]
# Out:
# 20

# %% [markdown]
# dataFrame, series의 행 열 갯수 세기
# - 행 개수 세기:
#     * 데이터프레임: len(df), df.shape[0], len(df.index)
#     * 시리즈: len(s), s.size, len(s.index)
# - 열 개수 세기:
#     * 데이터프레임: df.shape[1], len(df.columns)

# %% [markdown]
# 넘파이 배열 생성

# %%
# seq = DODI_C_20.iloc[:,[0, 1]]
# seq.dropna(axis=0, inplace= True)
# seq = DODI_C_20.iloc[:,[2, 3]]
# seq.dropna(axis=0, inplace= True)
# seq = DODI_C_20.iloc[:,[4, 5]]
# seq.dropna(axis=0, inplace= True)
# seq = DODI_C_20.iloc[:,[6, 7]]
# seq.dropna(axis=0, inplace= True)
# seq = DODI_C_20.iloc[:,[8, 9]]
# seq.dropna(axis=0, inplace= True)
# seq = DODI_C_20.iloc[:,[10, 11]]
# seq.dropna(axis=0, inplace= True)
# seq = DODI_C_20.iloc[:,[12, 13]]
# seq.dropna(axis=0, inplace= True)
# seq = DODI_C_20.iloc[:,[14, 15]]
# seq.dropna(axis=0, inplace= True)
# seq = DODI_C_20.iloc[:,[16, 17]]
# seq.dropna(axis=0, inplace= True)
# seq = DODI_C_20.iloc[:,[18, 19]]
# seq.dropna(axis=0, inplace= True)

# seq = seq.to_numpy()

# a = np.array(seq.shape[0], dtype = float)
# a = np.full((seq.shape[0],1),-20)
# seq = np.append(seq, a[:,-1:], axis = 1)

# %% [markdown]
# 튀는 값 제거해서 다시 비교해보기

# %%
#시계열 데이터를 윈도우 단위로 자르는 함수
def seq2dataset(seq,window,horizon):
    X=[]; Y=[]
    for i in range(len(seq)-(window+horizon)+1):
        x=seq[i:(i+window)]
        y=(seq[i+window+horizon-1])
        X.append(x); Y.append(y)
    return np.array(X), np.array(Y)

# %% [markdown]
# 온도는 절대온도

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, Conv3D, Conv1D
from sklearn.model_selection import KFold

# %%
def getColumnData(dataFrame):
    len = (int)(dataFrame.shape[1]/2)
    for i in range(len):
        seq = dataFrame.iloc[:,[2*i,2*i+1]]
        seq.dropna(axis=0, inplace=True)
        seq = seq.to_numpy()
        a = np.array(seq.shape[0], dtype = float)
        a = np.full((seq.shape[0],1),-20)
        seq = np.append(seq, a[:,-1:], axis = 1)
        
        kfold = KFold(n_splits=5)
        
        X,Y = seq2dataset(seq,10,1)
        for train_idx, test_idx in kfold.split(X):
            x_train, x_test = X[train_idx],X[test_idx]
            y_train, y_test = Y[train_idx],Y[test_idx]
        # split = X.shape[0]*0.7
        # split = round(split)
        # x_train = X[0:split]; y_train=Y[0:split]
        # x_test = X[split:]; y_test=Y[split:]

            model = Sequential()
            model.add(Conv1D(filters = 256, kernel_size = 3, input_shape = (10, 3),padding = 'same', activation = 'relu'))
            model.add(Dropout(0.2))
            model.add(Conv1D(filters = 256, kernel_size = 3, padding = 'same', activation = 'relu'))
            model.add(Dropout(0.2))
            model.add(LSTM(units=128,input_shape=x_train[0].shape, return_sequences=True))
            model.add(LSTM(units=128, return_sequences=False))
            model.add(Dense(3))
            model.compile(loss='mae')
            model.compile(loss='mae', optimizer='adam', metrics='mae')
            hist=model.fit(x_train,y_train,epochs=5,batch_size=50,validation_data=(x_test,y_test),verbose=1)

            ev=model.evaluate(x_test,y_test,verbose=1)
            print("손실 함수:", ev[0], "MAE:", ev[1])

            pred=model.predict(x_test)
            
            division = x_test.shape[0]
            print("LSTM 평균절댓값백분율오차(MAPE):",sum(abs(y_test-pred)/y_test)/division)

            plt.plot(hist.history['mae'])
            plt.plot(hist.history['val_mae'])
            plt.title('Model mae')
            plt.ylabel('mae')
            plt.xlabel('Epoch')
            plt.legend(['Train','Validation'], loc='best')
            plt.grid()
            plt.show()
        
            plt.figure(figsize=(8,8))
            x_range=range(y_test.shape[0])
            plt.plot(x_range,y_test[x_range,1],color='red',linestyle='dotted')
            plt.plot(x_range,pred[x_range,1],color='green',linestyle='dashed')
            plt.legend(['True value','Predicted value'], loc='best')
            plt.grid()
            plt.show()
            
            pred = model.predict(X)
            y_test = Y
            
            plt.figure(figsize=(8,8))
            x_range=range(y_test.shape[0])
            plt.plot(x_range,y_test[x_range,1],color='red',linestyle='dotted')
            plt.plot(x_range,pred[x_range,1],color='green',linestyle='dashed')
            plt.legend(['True value','Predicted value'], loc='best')
            plt.grid()
            plt.show()

# %%
getColumnData(DODI_C_20)
# Out:
# /Users/ohyeonsu/miniforge3/envs/tf25/lib/python3.8/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# Epoch 1/5
# 58/58 [==============================] - 12s 109ms/step - loss: 3.3057 - mae: 3.3057 - val_loss: 1.5714 - val_mae: 1.5714
# Epoch 2/5
# 58/58 [==============================] - 3s 47ms/step - loss: 0.6105 - mae: 0.6105 - val_loss: 1.3387 - val_mae: 1.3387
# Epoch 3/5
# 58/58 [==============================] - 3s 59ms/step - loss: 0.5509 - mae: 0.5509 - val_loss: 1.3654 - val_mae: 1.3654
# Epoch 4/5
# 58/58 [==============================] - 3s 52ms/step - loss: 0.5502 - mae: 0.5502 - val_loss: 1.3849 - val_mae: 1.3849
# Epoch 5/5
# 58/58 [==============================] - 3s 60ms/step - loss: 0.5466 - mae: 0.5466 - val_loss: 1.2601 - val_mae: 1.2601
# 23/23 [==============================] - 1s 29ms/step - loss: 1.2601 - mae: 1.2601
# 손실 함수: 1.2601248025894165 MAE: 1.2601248025894165
# LSTM 평균절댓값백분율오차(MAPE): [ 1.04632259e+01  4.32624732e-02 -3.66845164e-04]
# Epoch 1/5
# 58/58 [==============================] - 9s 103ms/step - loss: 3.0503 - mae: 3.0503 - val_loss: 0.7518 - val_mae: 0.7518
# Epoch 2/5
# 58/58 [==============================] - 4s 66ms/step - loss: 0.7276 - mae: 0.7276 - val_loss: 0.7829 - val_mae: 0.7829
# Epoch 3/5
# 58/58 [==============================] - 3s 59ms/step - loss: 0.6974 - mae: 0.6974 - val_loss: 0.7834 - val_mae: 0.7834
# Epoch 4/5
# 58/58 [==============================] - 4s 63ms/step - loss: 0.6825 - mae: 0.6825 - val_loss: 0.7221 - val_mae: 0.7221
# Epoch 5/5
# 58/58 [==============================] - 3s 55ms/step - loss: 0.5699 - mae: 0.5699 - val_loss: 0.4711 - val_mae: 0.4711
# 23/23 [==============================] - 1s 26ms/step - loss: 0.4711 - mae: 0.4711
# 손실 함수: 0.47110357880592346 MAE: 0.47110357880592346
# LSTM 평균절댓값백분율오차(MAPE): [ 6.05697245e-01  2.17406700e-02 -4.08859520e-04]
# Epoch 1/5
# 58/58 [==============================] - 9s 103ms/step - loss: 3.2658 - mae: 3.2658 - val_loss: 0.2932 - val_mae: 0.2932
# Epoch 2/5
# 58/58 [==============================] - 3s 48ms/step - loss: 0.8684 - mae: 0.8684 - val_loss: 0.1533 - val_mae: 0.1533
# Epoch 3/5
# 58/58 [==============================] - 4s 63ms/step - loss: 0.8228 - mae: 0.8228 - val_loss: 0.2010 - val_mae: 0.2010
# Epoch 4/5
# 58/58 [==============================] - 5s 91ms/step - loss: 0.8245 - mae: 0.8245 - val_loss: 0.1556 - val_mae: 0.1556
# Epoch 5/5
# 58/58 [==============================] - 4s 64ms/step - loss: 0.8235 - mae: 0.8235 - val_loss: 0.1431 - val_mae: 0.1431
# 23/23 [==============================] - 1s 27ms/step - loss: 0.1431 - mae: 0.1431
# 손실 함수: 0.14307290315628052 MAE: 0.14307290315628052
# LSTM 평균절댓값백분율오차(MAPE): [ 0.09698129  0.00972005 -0.00078824]
# Epoch 1/5
# 58/58 [==============================] - 11s 138ms/step - loss: 2.8894 - mae: 2.8894 - val_loss: 0.8368 - val_mae: 0.8368
# Epoch 2/5
# 58/58 [==============================] - 5s 94ms/step - loss: 0.7141 - mae: 0.7141 - val_loss: 0.8456 - val_mae: 0.8456
# Epoch 3/5
# 58/58 [==============================] - 4s 62ms/step - loss: 0.6925 - mae: 0.6925 - val_loss: 0.8722 - val_mae: 0.8722
# Epoch 4/5
# 58/58 [==============================] - 3s 58ms/step - loss: 0.6897 - mae: 0.6897 - val_loss: 0.8131 - val_mae: 0.8131
# Epoch 5/5
# 58/58 [==============================] - 4s 72ms/step - loss: 0.5421 - mae: 0.5421 - val_loss: 0.3647 - val_mae: 0.3647
# 23/23 [==============================] - 1s 30ms/step - loss: 0.3647 - mae: 0.3647
# 손실 함수: 0.36470043659210205 MAE: 0.36470043659210205
# LSTM 평균절댓값백분율오차(MAPE): [ 0.17907264  0.01877018 -0.00088317]
# Epoch 1/5
# 58/58 [==============================] - 10s 115ms/step - loss: 2.9646 - mae: 2.9646 - val_loss: 1.4426 - val_mae: 1.4426
# Epoch 2/5
# 58/58 [==============================] - 4s 63ms/step - loss: 0.5833 - mae: 0.5833 - val_loss: 1.3362 - val_mae: 1.3362
# Epoch 3/5
# 58/58 [==============================] - 4s 65ms/step - loss: 0.5425 - mae: 0.5425 - val_loss: 1.4542 - val_mae: 1.4542
# Epoch 4/5
# 58/58 [==============================] - 4s 61ms/step - loss: 0.5417 - mae: 0.5417 - val_loss: 1.3642 - val_mae: 1.3642
# Epoch 5/5
# 58/58 [==============================] - 3s 57ms/step - loss: 0.4973 - mae: 0.4973 - val_loss: 1.2338 - val_mae: 1.2338
# 23/23 [==============================] - 1s 32ms/step - loss: 1.2338 - mae: 1.2338
# 손실 함수: 1.2338253259658813 MAE: 1.2338253259658813
# LSTM 평균절댓값백분율오차(MAPE): [ 0.47145965  0.14281252 -0.00058864]
# /Users/ohyeonsu/miniforge3/envs/tf25/lib/python3.8/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# Epoch 1/5
# 61/61 [==============================] - 12s 132ms/step - loss: 2.9436 - mae: 2.9436 - val_loss: 1.5796 - val_mae: 1.5796
# Epoch 2/5
# 61/61 [==============================] - 3s 47ms/step - loss: 0.6228 - mae: 0.6228 - val_loss: 1.4819 - val_mae: 1.4819
# Epoch 3/5
# 61/61 [==============================] - 3s 47ms/step - loss: 0.5827 - mae: 0.5827 - val_loss: 1.3812 - val_mae: 1.3812
# Epoch 4/5
# 61/61 [==============================] - 4s 61ms/step - loss: 0.5831 - mae: 0.5831 - val_loss: 1.4298 - val_mae: 1.4298
# Epoch 5/5
# 61/61 [==============================] - 4s 59ms/step - loss: 0.5718 - mae: 0.5718 - val_loss: 1.3409 - val_mae: 1.3409
# 24/24 [==============================] - 1s 27ms/step - loss: 1.3409 - mae: 1.3409
# 손실 함수: 1.3408806324005127 MAE: 1.3408806324005127
# LSTM 평균절댓값백분율오차(MAPE): [ 1.09608431e+01  2.17728372e-02 -7.91825160e-04]
# Epoch 1/5
# 61/61 [==============================] - 10s 111ms/step - loss: 3.0000 - mae: 3.0000 - val_loss: 0.9357 - val_mae: 0.9357
# Epoch 2/5
# 61/61 [==============================] - 4s 62ms/step - loss: 0.7638 - mae: 0.7638 - val_loss: 0.8570 - val_mae: 0.8570
# Epoch 3/5
# 61/61 [==============================] - 4s 65ms/step - loss: 0.7254 - mae: 0.7254 - val_loss: 0.8222 - val_mae: 0.8222
# Epoch 4/5
# 61/61 [==============================] - 3s 51ms/step - loss: 0.7287 - mae: 0.7287 - val_loss: 0.9091 - val_mae: 0.9091
# Epoch 5/5
# 61/61 [==============================] - 3s 49ms/step - loss: 0.7282 - mae: 0.7282 - val_loss: 0.8337 - val_mae: 0.8337
# 24/24 [==============================] - 1s 27ms/step - loss: 0.8337 - mae: 0.8337
# 손실 함수: 0.83367919921875 MAE: 0.83367919921875
# LSTM 평균절댓값백분율오차(MAPE): [ 1.01699762e+00  2.73762410e-02 -8.46679647e-04]
# Epoch 1/5
# 61/61 [==============================] - 10s 108ms/step - loss: 3.1361 - mae: 3.1361 - val_loss: 0.3034 - val_mae: 0.3034
# Epoch 2/5
# 61/61 [==============================] - 4s 62ms/step - loss: 0.8952 - mae: 0.8952 - val_loss: 0.2151 - val_mae: 0.2151
# Epoch 3/5
# 61/61 [==============================] - 3s 50ms/step - loss: 0.8599 - mae: 0.8599 - val_loss: 0.1584 - val_mae: 0.1584
# Epoch 4/5
# 61/61 [==============================] - 4s 63ms/step - loss: 0.6002 - mae: 0.6002 - val_loss: 0.4356 - val_mae: 0.4356
# Epoch 5/5
# 61/61 [==============================] - 4s 67ms/step - loss: 0.2450 - mae: 0.2450 - val_loss: 0.3550 - val_mae: 0.3550
# 24/24 [==============================] - 1s 28ms/step - loss: 0.3550 - mae: 0.3550
# 손실 함수: 0.3549642264842987 MAE: 0.3549642264842987
# LSTM 평균절댓값백분율오차(MAPE): [ 0.24364308  0.01825777 -0.00141321]
# Epoch 1/5
# 61/61 [==============================] - 10s 111ms/step - loss: 2.9304 - mae: 2.9304 - val_loss: 0.9036 - val_mae: 0.9036
# Epoch 2/5
# 61/61 [==============================] - 3s 49ms/step - loss: 0.7498 - mae: 0.7498 - val_loss: 0.8875 - val_mae: 0.8875
# Epoch 3/5
# 61/61 [==============================] - 3s 48ms/step - loss: 0.7287 - mae: 0.7287 - val_loss: 0.7650 - val_mae: 0.7650
# Epoch 4/5
# 61/61 [==============================] - 4s 63ms/step - loss: 0.6087 - mae: 0.6087 - val_loss: 0.3753 - val_mae: 0.3753
# Epoch 5/5
# 61/61 [==============================] - 4s 68ms/step - loss: 0.3014 - mae: 0.3014 - val_loss: 0.3771 - val_mae: 0.3771
# 24/24 [==============================] - 1s 29ms/step - loss: 0.3771 - mae: 0.3771
# 손실 함수: 0.3770844340324402 MAE: 0.3770844340324402
# LSTM 평균절댓값백분율오차(MAPE): [ 0.17588295  0.03860855 -0.0002475 ]
# Epoch 1/5
# 61/61 [==============================] - 12s 143ms/step - loss: 2.8868 - mae: 2.8868 - val_loss: 1.4852 - val_mae: 1.4852
# Epoch 2/5
# 61/61 [==============================] - 5s 80ms/step - loss: 0.6015 - mae: 0.6015 - val_loss: 1.3851 - val_mae: 1.3851
# Epoch 3/5
# 61/61 [==============================] - 4s 63ms/step - loss: 0.5738 - mae: 0.5738 - val_loss: 1.4530 - val_mae: 1.4530
# Epoch 4/5
# 61/61 [==============================] - 4s 73ms/step - loss: 0.5719 - mae: 0.5719 - val_loss: 1.4796 - val_mae: 1.4796
# Epoch 5/5
# 61/61 [==============================] - 4s 67ms/step - loss: 0.5353 - mae: 0.5353 - val_loss: 1.2580 - val_mae: 1.2580
# 24/24 [==============================] - 1s 28ms/step - loss: 1.2580 - mae: 1.2580
# 손실 함수: 1.2580375671386719 MAE: 1.2580375671386719
# LSTM 평균절댓값백분율오차(MAPE): [ 0.45411411  0.15904165 -0.00070767]
# /Users/ohyeonsu/miniforge3/envs/tf25/lib/python3.8/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# Epoch 1/5
# 61/61 [==============================] - 12s 130ms/step - loss: 3.0905 - mae: 3.0905 - val_loss: 1.5846 - val_mae: 1.5846
# Epoch 2/5
# 61/61 [==============================] - 4s 73ms/step - loss: 0.6289 - mae: 0.6289 - val_loss: 1.3030 - val_mae: 1.3030
# Epoch 3/5
# 61/61 [==============================] - 4s 59ms/step - loss: 0.5896 - mae: 0.5896 - val_loss: 1.4098 - val_mae: 1.4098
# Epoch 4/5
# 61/61 [==============================] - 4s 64ms/step - loss: 0.5867 - mae: 0.5867 - val_loss: 1.3241 - val_mae: 1.3241
# Epoch 5/5
# 61/61 [==============================] - 3s 54ms/step - loss: 0.5489 - mae: 0.5489 - val_loss: 1.1636 - val_mae: 1.1636
# 24/24 [==============================] - 1s 29ms/step - loss: 1.1636 - mae: 1.1636
# 손실 함수: 1.1636176109313965 MAE: 1.1636176109313965
# LSTM 평균절댓값백분율오차(MAPE): [ 9.63709328e+00  5.26325465e-03 -3.66538878e-03]
# Epoch 1/5
# 61/61 [==============================] - 10s 117ms/step - loss: 3.0286 - mae: 3.0286 - val_loss: 0.9961 - val_mae: 0.9961
# Epoch 2/5
# 61/61 [==============================] - 3s 56ms/step - loss: 0.7671 - mae: 0.7671 - val_loss: 0.9397 - val_mae: 0.9397
# Epoch 3/5
# 61/61 [==============================] - 5s 81ms/step - loss: 0.7328 - mae: 0.7328 - val_loss: 0.8123 - val_mae: 0.8123
# Epoch 4/5
# 61/61 [==============================] - 4s 74ms/step - loss: 0.6793 - mae: 0.6793 - val_loss: 0.7016 - val_mae: 0.7016
# Epoch 5/5
# 61/61 [==============================] - 4s 68ms/step - loss: 0.4755 - mae: 0.4755 - val_loss: 0.2839 - val_mae: 0.2839
# 24/24 [==============================] - 1s 36ms/step - loss: 0.2839 - mae: 0.2839
# 손실 함수: 0.2839316427707672 MAE: 0.2839316427707672
# LSTM 평균절댓값백분율오차(MAPE): [ 0.32670613  0.03142816 -0.00172896]
# Epoch 1/5
# 61/61 [==============================] - 22s 297ms/step - loss: 2.9877 - mae: 2.9877 - val_loss: 0.4337 - val_mae: 0.4337
# Epoch 2/5
# 61/61 [==============================] - 4s 59ms/step - loss: 0.8986 - mae: 0.8986 - val_loss: 0.2528 - val_mae: 0.2528
# Epoch 3/5
# 61/61 [==============================] - 4s 59ms/step - loss: 0.8756 - mae: 0.8756 - val_loss: 0.1819 - val_mae: 0.1819
# Epoch 4/5
# 61/61 [==============================] - 4s 68ms/step - loss: 0.8802 - mae: 0.8802 - val_loss: 0.1634 - val_mae: 0.1634
# Epoch 5/5
# 61/61 [==============================] - 4s 58ms/step - loss: 0.8774 - mae: 0.8774 - val_loss: 0.1622 - val_mae: 0.1622
# 24/24 [==============================] - 1s 42ms/step - loss: 0.1622 - mae: 0.1622
# 손실 함수: 0.1622312217950821 MAE: 0.1622312217950821
# LSTM 평균절댓값백분율오차(MAPE): [ 0.10092625  0.00607155 -0.00160621]
# Epoch 1/5
# 61/61 [==============================] - 14s 139ms/step - loss: 2.8366 - mae: 2.8366 - val_loss: 0.9016 - val_mae: 0.9016
# Epoch 2/5
# 61/61 [==============================] - 4s 63ms/step - loss: 0.7606 - mae: 0.7606 - val_loss: 0.8177 - val_mae: 0.8177
# Epoch 3/5
# 61/61 [==============================] - 4s 59ms/step - loss: 0.7293 - mae: 0.7293 - val_loss: 0.8212 - val_mae: 0.8212
# Epoch 4/5
# 61/61 [==============================] - 4s 65ms/step - loss: 0.6839 - mae: 0.6839 - val_loss: 0.6926 - val_mae: 0.6926
# Epoch 5/5
# 61/61 [==============================] - 4s 68ms/step - loss: 0.4636 - mae: 0.4636 - val_loss: 0.1693 - val_mae: 0.1693
# 24/24 [==============================] - 1s 41ms/step - loss: 0.1693 - mae: 0.1693
# 손실 함수: 0.1693117618560791 MAE: 0.1693117618560791
# LSTM 평균절댓값백분율오차(MAPE): [ 0.05865357  0.04101342 -0.00138151]
# Epoch 1/5
# 61/61 [==============================] - 13s 134ms/step - loss: 2.9254 - mae: 2.9254 - val_loss: 1.5189 - val_mae: 1.5189
# Epoch 2/5
# 61/61 [==============================] - 4s 58ms/step - loss: 0.6071 - mae: 0.6071 - val_loss: 1.5121 - val_mae: 1.5121
# Epoch 3/5
# 61/61 [==============================] - 3s 57ms/step - loss: 0.5699 - mae: 0.5699 - val_loss: 1.5488 - val_mae: 1.5488
# Epoch 4/5
# 61/61 [==============================] - 3s 55ms/step - loss: 0.5708 - mae: 0.5708 - val_loss: 1.5928 - val_mae: 1.5928
# Epoch 5/5
# 61/61 [==============================] - 3s 57ms/step - loss: 0.5288 - mae: 0.5288 - val_loss: 1.4401 - val_mae: 1.4401
# 24/24 [==============================] - 1s 41ms/step - loss: 1.4401 - mae: 1.4401
# 손실 함수: 1.4400861263275146 MAE: 1.4400861263275146
# LSTM 평균절댓값백분율오차(MAPE): [ 0.5186131   0.20057011 -0.00176066]
# /Users/ohyeonsu/miniforge3/envs/tf25/lib/python3.8/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# Epoch 1/5
# 59/59 [==============================] - 13s 140ms/step - loss: 2.9881 - mae: 2.9881 - val_loss: 1.4596 - val_mae: 1.4596
# Epoch 2/5
# 59/59 [==============================] - 4s 61ms/step - loss: 0.5989 - mae: 0.5989 - val_loss: 1.4025 - val_mae: 1.4025
# Epoch 3/5
# 59/59 [==============================] - 4s 66ms/step - loss: 0.5629 - mae: 0.5629 - val_loss: 1.2998 - val_mae: 1.2998
# Epoch 4/5
# 59/59 [==============================] - 4s 60ms/step - loss: 0.5483 - mae: 0.5483 - val_loss: 1.2279 - val_mae: 1.2279
# Epoch 5/5
# 59/59 [==============================] - 3s 58ms/step - loss: 0.4044 - mae: 0.4044 - val_loss: 0.8886 - val_mae: 0.8886
# 23/23 [==============================] - 1s 32ms/step - loss: 0.8886 - mae: 0.8886
# 손실 함수: 0.8886258602142334 MAE: 0.8886258602142334
# LSTM 평균절댓값백분율오차(MAPE): [ 7.67828530e+00  1.85777082e-02 -6.49426105e-04]
# Epoch 1/5
# 59/59 [==============================] - 14s 156ms/step - loss: 3.2795 - mae: 3.2795 - val_loss: 0.9874 - val_mae: 0.9874
# Epoch 2/5
# 59/59 [==============================] - 4s 64ms/step - loss: 0.7444 - mae: 0.7444 - val_loss: 0.8336 - val_mae: 0.8336
# Epoch 3/5
# 59/59 [==============================] - 4s 65ms/step - loss: 0.7000 - mae: 0.7000 - val_loss: 0.8304 - val_mae: 0.8304
# Epoch 4/5
# 59/59 [==============================] - 5s 77ms/step - loss: 0.6495 - mae: 0.6495 - val_loss: 0.5081 - val_mae: 0.5081
# Epoch 5/5
# 59/59 [==============================] - 4s 67ms/step - loss: 0.3580 - mae: 0.3580 - val_loss: 0.1132 - val_mae: 0.1132
# 23/23 [==============================] - 1s 43ms/step - loss: 0.1132 - mae: 0.1132
# 손실 함수: 0.11316435784101486 MAE: 0.11316435784101486
# LSTM 평균절댓값백분율오차(MAPE): [ 0.09444084  0.01643034 -0.00289762]
# Epoch 1/5
# 59/59 [==============================] - 13s 163ms/step - loss: 3.0789 - mae: 3.0789 - val_loss: 0.4060 - val_mae: 0.4060
# Epoch 2/5
# 59/59 [==============================] - 4s 69ms/step - loss: 0.8638 - mae: 0.8638 - val_loss: 0.1566 - val_mae: 0.1566
# Epoch 3/5
# 59/59 [==============================] - 5s 88ms/step - loss: 0.8253 - mae: 0.8253 - val_loss: 0.1970 - val_mae: 0.1970
# Epoch 4/5
# 59/59 [==============================] - 5s 83ms/step - loss: 0.6313 - mae: 0.6313 - val_loss: 0.1901 - val_mae: 0.1901
# Epoch 5/5
# 59/59 [==============================] - 5s 77ms/step - loss: 0.2803 - mae: 0.2803 - val_loss: 0.1074 - val_mae: 0.1074
# 23/23 [==============================] - 2s 58ms/step - loss: 0.1074 - mae: 0.1074
# 손실 함수: 0.1073608547449112 MAE: 0.1073608547449112
# LSTM 평균절댓값백분율오차(MAPE): [ 0.05129656  0.0112391  -0.0029918 ]
# Epoch 1/5
# 59/59 [==============================] - 16s 180ms/step - loss: 3.0762 - mae: 3.0762 - val_loss: 0.8886 - val_mae: 0.8886
# Epoch 2/5
# 59/59 [==============================] - 4s 76ms/step - loss: 0.7363 - mae: 0.7363 - val_loss: 0.8294 - val_mae: 0.8294
# Epoch 3/5
# 59/59 [==============================] - 4s 65ms/step - loss: 0.6993 - mae: 0.6993 - val_loss: 0.9795 - val_mae: 0.9795
# Epoch 4/5
# 59/59 [==============================] - 4s 75ms/step - loss: 0.6314 - mae: 0.6314 - val_loss: 0.5614 - val_mae: 0.5614
# Epoch 5/5
# 59/59 [==============================] - 4s 69ms/step - loss: 0.3460 - mae: 0.3460 - val_loss: 0.0998 - val_mae: 0.0998
# 23/23 [==============================] - 2s 52ms/step - loss: 0.0998 - mae: 0.0998
# 손실 함수: 0.09981776773929596 MAE: 0.09981776773929596
# LSTM 평균절댓값백분율오차(MAPE): [ 0.04415872  0.01109559 -0.0003742 ]
# Epoch 1/5
# 59/59 [==============================] - 16s 187ms/step - loss: 2.9452 - mae: 2.9452 - val_loss: 1.4796 - val_mae: 1.4796
# Epoch 2/5
# 59/59 [==============================] - 5s 78ms/step - loss: 0.5890 - mae: 0.5890 - val_loss: 1.3601 - val_mae: 1.3601
# Epoch 3/5
# 59/59 [==============================] - 5s 85ms/step - loss: 0.5612 - mae: 0.5612 - val_loss: 1.4878 - val_mae: 1.4878
# Epoch 4/5
# 59/59 [==============================] - 5s 83ms/step - loss: 0.5607 - mae: 0.5607 - val_loss: 1.3760 - val_mae: 1.3760
# Epoch 5/5
# 59/59 [==============================] - 4s 69ms/step - loss: 0.5418 - mae: 0.5418 - val_loss: 1.3175 - val_mae: 1.3175
# 23/23 [==============================] - 2s 51ms/step - loss: 1.3175 - mae: 1.3175
# 손실 함수: 1.3174891471862793 MAE: 1.3174891471862793
# LSTM 평균절댓값백분율오차(MAPE): [ 0.52452831  0.06264702 -0.00118383]
# /Users/ohyeonsu/miniforge3/envs/tf25/lib/python3.8/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# Epoch 1/5
# 60/60 [==============================] - 17s 208ms/step - loss: 2.9098 - mae: 2.9098 - val_loss: 1.4331 - val_mae: 1.4331
# Epoch 2/5
# 60/60 [==============================] - 5s 90ms/step - loss: 0.6112 - mae: 0.6112 - val_loss: 1.3537 - val_mae: 1.3537
# Epoch 3/5
# 60/60 [==============================] - 4s 74ms/step - loss: 0.5807 - mae: 0.5807 - val_loss: 1.4696 - val_mae: 1.4696
# Epoch 4/5
# 60/60 [==============================] - 5s 86ms/step - loss: 0.5834 - mae: 0.5834 - val_loss: 1.4026 - val_mae: 1.4026
# Epoch 5/5
# 60/60 [==============================] - 5s 81ms/step - loss: 0.5611 - mae: 0.5611 - val_loss: 1.2949 - val_mae: 1.2949
# 24/24 [==============================] - 2s 57ms/step - loss: 1.2949 - mae: 1.2949
# 손실 함수: 1.2949368953704834 MAE: 1.2949368953704834
# LSTM 평균절댓값백분율오차(MAPE): [ 1.06285859e+01  1.96261594e-02 -6.77439158e-04]
# Epoch 1/5
# 60/60 [==============================] - 15s 180ms/step - loss: 2.9988 - mae: 2.9988 - val_loss: 0.9832 - val_mae: 0.9832
# Epoch 2/5
# 60/60 [==============================] - 4s 75ms/step - loss: 0.7664 - mae: 0.7664 - val_loss: 0.8640 - val_mae: 0.8640
# Epoch 3/5
# 60/60 [==============================] - 4s 69ms/step - loss: 0.7249 - mae: 0.7249 - val_loss: 0.9281 - val_mae: 0.9281
# Epoch 4/5
# 60/60 [==============================] - 4s 62ms/step - loss: 0.7219 - mae: 0.7219 - val_loss: 0.8289 - val_mae: 0.8289
# Epoch 5/5
# 60/60 [==============================] - 4s 63ms/step - loss: 0.6302 - mae: 0.6302 - val_loss: 0.2888 - val_mae: 0.2888
# 24/24 [==============================] - 1s 42ms/step - loss: 0.2888 - mae: 0.2888
# 손실 함수: 0.28884652256965637 MAE: 0.28884652256965637
# LSTM 평균절댓값백분율오차(MAPE): [ 3.75410037e-01  8.45014089e-03 -1.74222601e-04]
# Epoch 1/5
# 60/60 [==============================] - 14s 164ms/step - loss: 3.0614 - mae: 3.0614 - val_loss: 0.4512 - val_mae: 0.4512
# Epoch 2/5
# 60/60 [==============================] - 4s 63ms/step - loss: 0.8936 - mae: 0.8936 - val_loss: 0.2212 - val_mae: 0.2212
# Epoch 3/5
# 60/60 [==============================] - 4s 69ms/step - loss: 0.8634 - mae: 0.8634 - val_loss: 0.2491 - val_mae: 0.2491
# Epoch 4/5
# 60/60 [==============================] - 4s 66ms/step - loss: 0.7420 - mae: 0.7420 - val_loss: 0.1677 - val_mae: 0.1677
# Epoch 5/5
# 60/60 [==============================] - 4s 64ms/step - loss: 0.3213 - mae: 0.3213 - val_loss: 0.1902 - val_mae: 0.1902
# 24/24 [==============================] - 1s 42ms/step - loss: 0.1902 - mae: 0.1902
# 손실 함수: 0.19024956226348877 MAE: 0.19024956226348877
# LSTM 평균절댓값백분율오차(MAPE): [ 0.09852069  0.03591281 -0.00157736]
# Epoch 1/5
# 60/60 [==============================] - 14s 164ms/step - loss: 2.9483 - mae: 2.9483 - val_loss: 0.9446 - val_mae: 0.9446
# Epoch 2/5
# 60/60 [==============================] - 4s 65ms/step - loss: 0.7545 - mae: 0.7545 - val_loss: 0.8335 - val_mae: 0.8335
# Epoch 3/5
# 60/60 [==============================] - 4s 66ms/step - loss: 0.7336 - mae: 0.7336 - val_loss: 0.8049 - val_mae: 0.8049
# Epoch 4/5
# 60/60 [==============================] - 4s 65ms/step - loss: 0.7316 - mae: 0.7316 - val_loss: 0.8222 - val_mae: 0.8222
# Epoch 5/5
# 60/60 [==============================] - 4s 65ms/step - loss: 0.7302 - mae: 0.7302 - val_loss: 0.7623 - val_mae: 0.7623
# 24/24 [==============================] - 1s 41ms/step - loss: 0.7623 - mae: 0.7623
# 손실 함수: 0.7623288631439209 MAE: 0.7623288631439209
# LSTM 평균절댓값백분율오차(MAPE): [ 0.38286821  0.01266693 -0.00152877]
# Epoch 1/5
# 60/60 [==============================] - 14s 158ms/step - loss: 2.8521 - mae: 2.8521 - val_loss: 1.5578 - val_mae: 1.5578
# Epoch 2/5
# 60/60 [==============================] - 4s 68ms/step - loss: 0.6004 - mae: 0.6004 - val_loss: 1.4674 - val_mae: 1.4674
# Epoch 3/5
# 60/60 [==============================] - 4s 64ms/step - loss: 0.5666 - mae: 0.5666 - val_loss: 1.5077 - val_mae: 1.5077
# Epoch 4/5
# 60/60 [==============================] - 4s 68ms/step - loss: 0.5499 - mae: 0.5499 - val_loss: 1.3914 - val_mae: 1.3914
# Epoch 5/5
# 60/60 [==============================] - 4s 66ms/step - loss: 0.4159 - mae: 0.4159 - val_loss: 1.1819 - val_mae: 1.1819
# 24/24 [==============================] - 1s 41ms/step - loss: 1.1819 - mae: 1.1819
# 손실 함수: 1.1819243431091309 MAE: 1.1819243431091309
# LSTM 평균절댓값백분율오차(MAPE): [ 0.42532505  0.17654198 -0.0010283 ]
# /Users/ohyeonsu/miniforge3/envs/tf25/lib/python3.8/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# Epoch 1/5
# 60/60 [==============================] - 14s 162ms/step - loss: 3.0980 - mae: 3.0980 - val_loss: 1.6266 - val_mae: 1.6266
# Epoch 2/5
# 60/60 [==============================] - 4s 65ms/step - loss: 0.6175 - mae: 0.6175 - val_loss: 1.4139 - val_mae: 1.4139
# Epoch 3/5
# 60/60 [==============================] - 4s 62ms/step - loss: 0.5802 - mae: 0.5802 - val_loss: 1.3639 - val_mae: 1.3639
# Epoch 4/5
# 60/60 [==============================] - 4s 67ms/step - loss: 0.5791 - mae: 0.5791 - val_loss: 1.4664 - val_mae: 1.4664
# Epoch 5/5
# 60/60 [==============================] - 4s 65ms/step - loss: 0.5779 - mae: 0.5779 - val_loss: 1.4139 - val_mae: 1.4139
# 24/24 [==============================] - 1s 38ms/step - loss: 1.4139 - mae: 1.4139
# 손실 함수: 1.4138693809509277 MAE: 1.4138693809509277
# LSTM 평균절댓값백분율오차(MAPE): [ 1.14427278e+01  3.56095051e-02 -3.60414262e-04]
# Epoch 1/5
# 60/60 [==============================] - 14s 158ms/step - loss: 3.0683 - mae: 3.0683 - val_loss: 0.8510 - val_mae: 0.8510
# Epoch 2/5
# 60/60 [==============================] - 4s 66ms/step - loss: 0.7486 - mae: 0.7486 - val_loss: 0.8128 - val_mae: 0.8128
# Epoch 3/5
# 60/60 [==============================] - 4s 62ms/step - loss: 0.7238 - mae: 0.7238 - val_loss: 0.8719 - val_mae: 0.8719
# Epoch 4/5
# 60/60 [==============================] - 4s 69ms/step - loss: 0.6499 - mae: 0.6499 - val_loss: 0.6296 - val_mae: 0.6296
# Epoch 5/5
# 60/60 [==============================] - 4s 73ms/step - loss: 0.3835 - mae: 0.3835 - val_loss: 0.0751 - val_mae: 0.0751
# 24/24 [==============================] - 2s 55ms/step - loss: 0.0751 - mae: 0.0751
# 손실 함수: 0.07508164644241333 MAE: 0.07508164644241333
# LSTM 평균절댓값백분율오차(MAPE): [ 0.08408564  0.00926126 -0.00123325]
# Epoch 1/5
# 60/60 [==============================] - 20s 218ms/step - loss: 3.1181 - mae: 3.1181 - val_loss: 0.2147 - val_mae: 0.2147
# Epoch 2/5
# 60/60 [==============================] - 5s 81ms/step - loss: 0.8920 - mae: 0.8920 - val_loss: 0.1590 - val_mae: 0.1590
# Epoch 3/5
# 60/60 [==============================] - 4s 71ms/step - loss: 0.8727 - mae: 0.8727 - val_loss: 0.1972 - val_mae: 0.1972
# Epoch 4/5
# 60/60 [==============================] - 5s 82ms/step - loss: 0.8544 - mae: 0.8544 - val_loss: 0.2117 - val_mae: 0.2117
# Epoch 5/5
# 60/60 [==============================] - 6s 92ms/step - loss: 0.5437 - mae: 0.5437 - val_loss: 0.0865 - val_mae: 0.0865
# 24/24 [==============================] - 2s 50ms/step - loss: 0.0865 - mae: 0.0865
# 손실 함수: 0.08654190599918365 MAE: 0.08654190599918365
# LSTM 평균절댓값백분율오차(MAPE): [ 0.04306664  0.01630577 -0.00123313]
# Epoch 1/5
# 60/60 [==============================] - 18s 212ms/step - loss: 2.9107 - mae: 2.9107 - val_loss: 0.9031 - val_mae: 0.9031
# Epoch 2/5
# 60/60 [==============================] - 7s 116ms/step - loss: 0.7522 - mae: 0.7522 - val_loss: 0.7450 - val_mae: 0.7450
# Epoch 3/5
# 60/60 [==============================] - 6s 99ms/step - loss: 0.7263 - mae: 0.7263 - val_loss: 0.8595 - val_mae: 0.8595
# Epoch 4/5
# 60/60 [==============================] - 5s 84ms/step - loss: 0.7053 - mae: 0.7053 - val_loss: 0.7013 - val_mae: 0.7013
# Epoch 5/5
# 60/60 [==============================] - 4s 74ms/step - loss: 0.6435 - mae: 0.6435 - val_loss: 0.6340 - val_mae: 0.6340
# 24/24 [==============================] - 1s 43ms/step - loss: 0.6340 - mae: 0.6340
# 손실 함수: 0.6339901089668274 MAE: 0.6339901089668274
# LSTM 평균절댓값백분율오차(MAPE): [ 0.30887015  0.02734897 -0.00114361]
# Epoch 1/5
# 60/60 [==============================] - 17s 196ms/step - loss: 2.8201 - mae: 2.8201 - val_loss: 1.6008 - val_mae: 1.6008
# Epoch 2/5
# 60/60 [==============================] - 5s 87ms/step - loss: 0.5973 - mae: 0.5973 - val_loss: 1.4824 - val_mae: 1.4824
# Epoch 3/5
# 60/60 [==============================] - 4s 69ms/step - loss: 0.5654 - mae: 0.5654 - val_loss: 1.4390 - val_mae: 1.4390
# Epoch 4/5
# 60/60 [==============================] - 4s 69ms/step - loss: 0.5595 - mae: 0.5595 - val_loss: 1.4974 - val_mae: 1.4974
# Epoch 5/5
# 60/60 [==============================] - 4s 73ms/step - loss: 0.4467 - mae: 0.4467 - val_loss: 0.9970 - val_mae: 0.9970
# 24/24 [==============================] - 2s 46ms/step - loss: 0.9970 - mae: 0.9970
# 손실 함수: 0.9969682693481445 MAE: 0.9969682693481445
# LSTM 평균절댓값백분율오차(MAPE): [ 0.36103081  0.13412288 -0.00142812]
# /Users/ohyeonsu/miniforge3/envs/tf25/lib/python3.8/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# Epoch 1/5
# 60/60 [==============================] - 15s 164ms/step - loss: 2.8908 - mae: 2.8908 - val_loss: 1.5039 - val_mae: 1.5039
# Epoch 2/5
# 60/60 [==============================] - 5s 80ms/step - loss: 0.6066 - mae: 0.6066 - val_loss: 1.4063 - val_mae: 1.4063
# Epoch 3/5
# 60/60 [==============================] - 5s 82ms/step - loss: 0.5787 - mae: 0.5787 - val_loss: 1.4131 - val_mae: 1.4131
# Epoch 4/5
# 60/60 [==============================] - 5s 76ms/step - loss: 0.5785 - mae: 0.5785 - val_loss: 1.4190 - val_mae: 1.4190
# Epoch 5/5
# 60/60 [==============================] - 4s 75ms/step - loss: 0.5797 - mae: 0.5797 - val_loss: 1.3852 - val_mae: 1.3852
# 24/24 [==============================] - 1s 44ms/step - loss: 1.3852 - mae: 1.3852
# 손실 함수: 1.3852019309997559 MAE: 1.3852019309997559
# LSTM 평균절댓값백분율오차(MAPE): [ 1.13586106e+01  2.59414697e-02 -5.93669284e-04]
# Epoch 1/5
# 60/60 [==============================] - 15s 170ms/step - loss: 3.0945 - mae: 3.0945 - val_loss: 0.9346 - val_mae: 0.9346
# Epoch 2/5
# 60/60 [==============================] - 5s 77ms/step - loss: 0.7510 - mae: 0.7510 - val_loss: 0.8401 - val_mae: 0.8401
# Epoch 3/5
# 60/60 [==============================] - 5s 79ms/step - loss: 0.7211 - mae: 0.7211 - val_loss: 0.7469 - val_mae: 0.7469
# Epoch 4/5
# 60/60 [==============================] - 4s 67ms/step - loss: 0.7156 - mae: 0.7156 - val_loss: 0.7743 - val_mae: 0.7743
# Epoch 5/5
# 60/60 [==============================] - 4s 73ms/step - loss: 0.6404 - mae: 0.6404 - val_loss: 0.7086 - val_mae: 0.7086
# 24/24 [==============================] - 2s 58ms/step - loss: 0.7086 - mae: 0.7086
# 손실 함수: 0.7085697650909424 MAE: 0.7085697650909424
# LSTM 평균절댓값백분율오차(MAPE): [ 0.88705835  0.0147486  -0.00113636]
# Epoch 1/5
# 60/60 [==============================] - 17s 202ms/step - loss: 3.0620 - mae: 3.0620 - val_loss: 0.3447 - val_mae: 0.3447
# Epoch 2/5
# 60/60 [==============================] - 4s 67ms/step - loss: 0.8950 - mae: 0.8950 - val_loss: 0.1439 - val_mae: 0.1439
# Epoch 3/5
# 60/60 [==============================] - 4s 69ms/step - loss: 0.8604 - mae: 0.8604 - val_loss: 0.1659 - val_mae: 0.1659
# Epoch 4/5
# 60/60 [==============================] - 4s 64ms/step - loss: 0.8594 - mae: 0.8594 - val_loss: 0.1613 - val_mae: 0.1613
# Epoch 5/5
# 60/60 [==============================] - 4s 65ms/step - loss: 0.8608 - mae: 0.8608 - val_loss: 0.1660 - val_mae: 0.1660
# 24/24 [==============================] - 1s 43ms/step - loss: 0.1660 - mae: 0.1660
# 손실 함수: 0.16595329344272614 MAE: 0.16595329344272614
# LSTM 평균절댓값백분율오차(MAPE): [ 0.10436656  0.01171077 -0.00054995]
# Epoch 1/5
# 60/60 [==============================] - 15s 170ms/step - loss: 2.9084 - mae: 2.9084 - val_loss: 0.9686 - val_mae: 0.9686
# Epoch 2/5
# 60/60 [==============================] - 4s 71ms/step - loss: 0.7416 - mae: 0.7416 - val_loss: 0.7860 - val_mae: 0.7860
# Epoch 3/5
# 60/60 [==============================] - 4s 68ms/step - loss: 0.7200 - mae: 0.7200 - val_loss: 0.8707 - val_mae: 0.8707
# Epoch 4/5
# 60/60 [==============================] - 4s 68ms/step - loss: 0.7076 - mae: 0.7076 - val_loss: 0.7041 - val_mae: 0.7041
# Epoch 5/5
# 60/60 [==============================] - 4s 68ms/step - loss: 0.5195 - mae: 0.5195 - val_loss: 0.3594 - val_mae: 0.3594
# 24/24 [==============================] - 2s 48ms/step - loss: 0.3594 - mae: 0.3594
# 손실 함수: 0.35936233401298523 MAE: 0.35936233401298523
# LSTM 평균절댓값백분율오차(MAPE): [ 0.17721664  0.00372225 -0.00100639]
# Epoch 1/5
# 60/60 [==============================] - 14s 165ms/step - loss: 2.9587 - mae: 2.9587 - val_loss: 1.4413 - val_mae: 1.4413
# Epoch 2/5
# 60/60 [==============================] - 4s 70ms/step - loss: 0.5960 - mae: 0.5960 - val_loss: 1.5120 - val_mae: 1.5120
# Epoch 3/5
# 60/60 [==============================] - 4s 69ms/step - loss: 0.5547 - mae: 0.5547 - val_loss: 1.4034 - val_mae: 1.4034
# Epoch 4/5
# 60/60 [==============================] - 4s 68ms/step - loss: 0.4691 - mae: 0.4691 - val_loss: 1.0477 - val_mae: 1.0477
# Epoch 5/5
# 60/60 [==============================] - 4s 69ms/step - loss: 0.2018 - mae: 0.2018 - val_loss: 0.6990 - val_mae: 0.6990
# 24/24 [==============================] - 1s 41ms/step - loss: 0.6990 - mae: 0.6990
# 손실 함수: 0.6989960074424744 MAE: 0.6989960074424744
# LSTM 평균절댓값백분율오차(MAPE): [ 2.35139612e-01  1.46571313e-01 -5.58652712e-05]
# /Users/ohyeonsu/miniforge3/envs/tf25/lib/python3.8/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# Epoch 1/5
# 60/60 [==============================] - 15s 169ms/step - loss: 3.1979 - mae: 3.1979 - val_loss: 1.4542 - val_mae: 1.4542
# Epoch 2/5
# 60/60 [==============================] - 4s 67ms/step - loss: 0.6128 - mae: 0.6128 - val_loss: 1.4629 - val_mae: 1.4629
# Epoch 3/5
# 60/60 [==============================] - 4s 71ms/step - loss: 0.5778 - mae: 0.5778 - val_loss: 1.3695 - val_mae: 1.3695
# Epoch 4/5
# 60/60 [==============================] - 4s 69ms/step - loss: 0.5763 - mae: 0.5763 - val_loss: 1.3973 - val_mae: 1.3973
# Epoch 5/5
# 60/60 [==============================] - 4s 66ms/step - loss: 0.5753 - mae: 0.5753 - val_loss: 1.4279 - val_mae: 1.4279
# 24/24 [==============================] - 1s 45ms/step - loss: 1.4279 - mae: 1.4279
# 손실 함수: 1.4278793334960938 MAE: 1.4278793334960938
# LSTM 평균절댓값백분율오차(MAPE): [ 1.18507698e+01  2.80653522e-02 -6.81172163e-04]
# Epoch 1/5
# 60/60 [==============================] - 15s 175ms/step - loss: 3.1245 - mae: 3.1245 - val_loss: 0.8200 - val_mae: 0.8200
# Epoch 2/5
# 60/60 [==============================] - 4s 72ms/step - loss: 0.7521 - mae: 0.7521 - val_loss: 0.8170 - val_mae: 0.8170
# Epoch 3/5
# 60/60 [==============================] - 4s 68ms/step - loss: 0.7212 - mae: 0.7212 - val_loss: 0.8851 - val_mae: 0.8851
# Epoch 4/5
# 60/60 [==============================] - 5s 81ms/step - loss: 0.7131 - mae: 0.7131 - val_loss: 0.7897 - val_mae: 0.7897
# Epoch 5/5
# 60/60 [==============================] - 4s 73ms/step - loss: 0.5682 - mae: 0.5682 - val_loss: 0.3733 - val_mae: 0.3733
# 24/24 [==============================] - 1s 40ms/step - loss: 0.3733 - mae: 0.3733
# 손실 함수: 0.3732728660106659 MAE: 0.3732728660106659
# LSTM 평균절댓값백분율오차(MAPE): [ 0.46642886  0.00469085 -0.00265221]
# Epoch 1/5
# 60/60 [==============================] - 15s 164ms/step - loss: 3.0511 - mae: 3.0511 - val_loss: 0.5135 - val_mae: 0.5135
# Epoch 2/5
# 60/60 [==============================] - 4s 70ms/step - loss: 0.8847 - mae: 0.8847 - val_loss: 0.1587 - val_mae: 0.1587
# Epoch 3/5
# 60/60 [==============================] - 4s 67ms/step - loss: 0.8478 - mae: 0.8478 - val_loss: 0.1565 - val_mae: 0.1565
# Epoch 4/5
# 60/60 [==============================] - 4s 65ms/step - loss: 0.7333 - mae: 0.7333 - val_loss: 0.2113 - val_mae: 0.2113
# Epoch 5/5
# 60/60 [==============================] - 4s 66ms/step - loss: 0.3175 - mae: 0.3175 - val_loss: 0.1381 - val_mae: 0.1381
# 24/24 [==============================] - 1s 42ms/step - loss: 0.1381 - mae: 0.1381
# 손실 함수: 0.13813664019107819 MAE: 0.13813664019107819
# LSTM 평균절댓값백분율오차(MAPE): [ 0.07057922  0.03077809 -0.00137394]
# Epoch 1/5
# 60/60 [==============================] - 15s 168ms/step - loss: 2.8768 - mae: 2.8768 - val_loss: 0.9437 - val_mae: 0.9437
# Epoch 2/5
# 60/60 [==============================] - 4s 67ms/step - loss: 0.7438 - mae: 0.7438 - val_loss: 0.8366 - val_mae: 0.8366
# Epoch 3/5
# 60/60 [==============================] - 4s 66ms/step - loss: 0.7188 - mae: 0.7188 - val_loss: 0.7607 - val_mae: 0.7607
# Epoch 4/5
# 60/60 [==============================] - 4s 69ms/step - loss: 0.7058 - mae: 0.7058 - val_loss: 0.6851 - val_mae: 0.6851
# Epoch 5/5
# 60/60 [==============================] - 4s 68ms/step - loss: 0.5143 - mae: 0.5143 - val_loss: 0.4464 - val_mae: 0.4464
# 24/24 [==============================] - 1s 45ms/step - loss: 0.4464 - mae: 0.4464
# 손실 함수: 0.44635632634162903 MAE: 0.44635632634162903
# LSTM 평균절댓값백분율오차(MAPE): [ 0.20436694  0.04628548 -0.00023657]
# Epoch 1/5
# 60/60 [==============================] - 15s 170ms/step - loss: 2.8512 - mae: 2.8512 - val_loss: 1.5975 - val_mae: 1.5975
# Epoch 2/5
# 60/60 [==============================] - 4s 72ms/step - loss: 0.5936 - mae: 0.5936 - val_loss: 1.4979 - val_mae: 1.4979
# Epoch 3/5
# 60/60 [==============================] - 4s 70ms/step - loss: 0.5577 - mae: 0.5577 - val_loss: 1.5418 - val_mae: 1.5418
# Epoch 4/5
# 60/60 [==============================] - 4s 67ms/step - loss: 0.5165 - mae: 0.5165 - val_loss: 1.3575 - val_mae: 1.3575
# Epoch 5/5
# 60/60 [==============================] - 4s 66ms/step - loss: 0.2890 - mae: 0.2890 - val_loss: 0.8733 - val_mae: 0.8733
# 24/24 [==============================] - 1s 47ms/step - loss: 0.8733 - mae: 0.8733
# 손실 함수: 0.8732779026031494 MAE: 0.8732779026031494
# LSTM 평균절댓값백분율오차(MAPE): [ 0.30654301  0.15850795 -0.00049999]
# /Users/ohyeonsu/miniforge3/envs/tf25/lib/python3.8/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# Epoch 1/5
# 58/58 [==============================] - 15s 171ms/step - loss: 2.9670 - mae: 2.9670 - val_loss: 1.4744 - val_mae: 1.4744
# Epoch 2/5
# 58/58 [==============================] - 4s 71ms/step - loss: 0.5858 - mae: 0.5858 - val_loss: 1.3486 - val_mae: 1.3486
# Epoch 3/5
# 58/58 [==============================] - 4s 69ms/step - loss: 0.5542 - mae: 0.5542 - val_loss: 1.2863 - val_mae: 1.2863
# Epoch 4/5
# 58/58 [==============================] - 4s 69ms/step - loss: 0.5516 - mae: 0.5516 - val_loss: 1.3138 - val_mae: 1.3138
# Epoch 5/5
# 58/58 [==============================] - 4s 68ms/step - loss: 0.5238 - mae: 0.5238 - val_loss: 1.2371 - val_mae: 1.2371
# 23/23 [==============================] - 1s 40ms/step - loss: 1.2371 - mae: 1.2371
# 손실 함수: 1.2370599508285522 MAE: 1.2370599508285522
# LSTM 평균절댓값백분율오차(MAPE): [ 1.05032686e+01  1.10713959e-02 -1.07696957e-03]
# Epoch 1/5
# 58/58 [==============================] - 15s 175ms/step - loss: 3.0136 - mae: 3.0136 - val_loss: 0.8189 - val_mae: 0.8189
# Epoch 2/5
# 58/58 [==============================] - 4s 68ms/step - loss: 0.7248 - mae: 0.7248 - val_loss: 0.8112 - val_mae: 0.8112
# Epoch 3/5
# 58/58 [==============================] - 4s 70ms/step - loss: 0.6918 - mae: 0.6918 - val_loss: 0.7455 - val_mae: 0.7455
# Epoch 4/5
# 58/58 [==============================] - 4s 67ms/step - loss: 0.5342 - mae: 0.5342 - val_loss: 0.3402 - val_mae: 0.3402
# Epoch 5/5
# 58/58 [==============================] - 4s 66ms/step - loss: 0.2569 - mae: 0.2569 - val_loss: 0.2983 - val_mae: 0.2983
# 23/23 [==============================] - 1s 44ms/step - loss: 0.2983 - mae: 0.2983
# 손실 함수: 0.29833945631980896 MAE: 0.29833945631980896
# LSTM 평균절댓값백분율오차(MAPE): [ 0.35551026  0.02551666 -0.00064905]
# Epoch 1/5
# 58/58 [==============================] - 15s 171ms/step - loss: 3.1293 - mae: 3.1293 - val_loss: 0.1736 - val_mae: 0.1736
# Epoch 2/5
# 58/58 [==============================] - 4s 69ms/step - loss: 0.8493 - mae: 0.8493 - val_loss: 0.1500 - val_mae: 0.1500
# Epoch 3/5
# 58/58 [==============================] - 4s 62ms/step - loss: 0.7388 - mae: 0.7388 - val_loss: 0.1435 - val_mae: 0.1435
# Epoch 4/5
# 58/58 [==============================] - 4s 64ms/step - loss: 0.4091 - mae: 0.4091 - val_loss: 0.3789 - val_mae: 0.3789
# Epoch 5/5
# 58/58 [==============================] - 4s 64ms/step - loss: 0.2033 - mae: 0.2033 - val_loss: 0.2632 - val_mae: 0.2632
# 23/23 [==============================] - 1s 42ms/step - loss: 0.2632 - mae: 0.2632
# 손실 함수: 0.26322656869888306 MAE: 0.26322656869888306
# LSTM 평균절댓값백분율오차(MAPE): [ 0.16506939  0.03067015 -0.00271837]
# Epoch 1/5
# 58/58 [==============================] - 15s 176ms/step - loss: 3.0347 - mae: 3.0347 - val_loss: 0.7811 - val_mae: 0.7811
# Epoch 2/5
# 58/58 [==============================] - 4s 68ms/step - loss: 0.7187 - mae: 0.7187 - val_loss: 0.7754 - val_mae: 0.7754
# Epoch 3/5
# 58/58 [==============================] - 4s 66ms/step - loss: 0.6906 - mae: 0.6906 - val_loss: 0.7809 - val_mae: 0.7809
# Epoch 4/5
# 58/58 [==============================] - 4s 66ms/step - loss: 0.6820 - mae: 0.6820 - val_loss: 0.7554 - val_mae: 0.7554
# Epoch 5/5
# 58/58 [==============================] - 4s 63ms/step - loss: 0.6234 - mae: 0.6234 - val_loss: 0.5210 - val_mae: 0.5210
# 23/23 [==============================] - 1s 42ms/step - loss: 0.5210 - mae: 0.5210
# 손실 함수: 0.520965576171875 MAE: 0.520965576171875
# LSTM 평균절댓값백분율오차(MAPE): [ 0.27183825  0.0051116  -0.00040179]
# Epoch 1/5
# 58/58 [==============================] - 15s 175ms/step - loss: 2.8147 - mae: 2.8147 - val_loss: 1.3070 - val_mae: 1.3070
# Epoch 2/5
# 58/58 [==============================] - 4s 69ms/step - loss: 0.5881 - mae: 0.5881 - val_loss: 1.3783 - val_mae: 1.3783
# Epoch 3/5
# 58/58 [==============================] - 4s 65ms/step - loss: 0.5444 - mae: 0.5444 - val_loss: 1.2817 - val_mae: 1.2817
# Epoch 4/5
# 58/58 [==============================] - 4s 69ms/step - loss: 0.5489 - mae: 0.5489 - val_loss: 1.4018 - val_mae: 1.4018
# Epoch 5/5
# 58/58 [==============================] - 4s 69ms/step - loss: 0.5313 - mae: 0.5313 - val_loss: 1.3120 - val_mae: 1.3120
# 23/23 [==============================] - 1s 44ms/step - loss: 1.3120 - mae: 1.3120
# 손실 함수: 1.3120135068893433 MAE: 1.3120135068893433
# LSTM 평균절댓값백분율오차(MAPE): [ 5.24745744e-01  8.15082453e-02 -3.31550646e-04]
# /Users/ohyeonsu/miniforge3/envs/tf25/lib/python3.8/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# Epoch 1/5
# 61/61 [==============================] - 15s 175ms/step - loss: 3.1513 - mae: 3.1513 - val_loss: 1.6671 - val_mae: 1.6671
# Epoch 2/5
# 61/61 [==============================] - 4s 69ms/step - loss: 0.6171 - mae: 0.6171 - val_loss: 1.2939 - val_mae: 1.2939
# Epoch 3/5
# 61/61 [==============================] - 4s 64ms/step - loss: 0.5854 - mae: 0.5854 - val_loss: 1.4024 - val_mae: 1.4024
# Epoch 4/5
# 61/61 [==============================] - 4s 67ms/step - loss: 0.5822 - mae: 0.5822 - val_loss: 1.4217 - val_mae: 1.4217
# Epoch 5/5
# 61/61 [==============================] - 4s 65ms/step - loss: 0.5809 - mae: 0.5809 - val_loss: 1.4197 - val_mae: 1.4197
# 24/24 [==============================] - 1s 46ms/step - loss: 1.4197 - mae: 1.4197
# 손실 함수: 1.4197230339050293 MAE: 1.4197230339050293
# LSTM 평균절댓값백분율오차(MAPE): [ 1.12365628e+01  4.10276567e-02 -7.59311554e-04]
# Epoch 1/5
# 61/61 [==============================] - 15s 170ms/step - loss: 3.1055 - mae: 3.1055 - val_loss: 0.8052 - val_mae: 0.8052
# Epoch 2/5
# 61/61 [==============================] - 4s 67ms/step - loss: 0.7687 - mae: 0.7687 - val_loss: 0.9105 - val_mae: 0.9105
# Epoch 3/5
# 61/61 [==============================] - 4s 67ms/step - loss: 0.7315 - mae: 0.7315 - val_loss: 0.8931 - val_mae: 0.8931
# Epoch 4/5
# 61/61 [==============================] - 4s 68ms/step - loss: 0.7266 - mae: 0.7266 - val_loss: 0.7513 - val_mae: 0.7513
# Epoch 5/5
# 61/61 [==============================] - 4s 69ms/step - loss: 0.6588 - mae: 0.6588 - val_loss: 0.5460 - val_mae: 0.5460
# 24/24 [==============================] - 1s 41ms/step - loss: 0.5460 - mae: 0.5460
# 손실 함수: 0.5459554195404053 MAE: 0.5459554195404053
# LSTM 평균절댓값백분율오차(MAPE): [ 6.92543827e-01  4.96529479e-03 -3.87754199e-04]
# Epoch 1/5
# 61/61 [==============================] - 15s 166ms/step - loss: 3.0252 - mae: 3.0252 - val_loss: 0.2916 - val_mae: 0.2916
# Epoch 2/5
# 61/61 [==============================] - 4s 69ms/step - loss: 0.8978 - mae: 0.8978 - val_loss: 0.1861 - val_mae: 0.1861
# Epoch 3/5
# 61/61 [==============================] - 4s 67ms/step - loss: 0.8524 - mae: 0.8524 - val_loss: 0.1575 - val_mae: 0.1575
# Epoch 4/5
# 61/61 [==============================] - 4s 66ms/step - loss: 0.6580 - mae: 0.6580 - val_loss: 0.2563 - val_mae: 0.2563
# Epoch 5/5
# 61/61 [==============================] - 4s 63ms/step - loss: 0.2622 - mae: 0.2622 - val_loss: 0.1838 - val_mae: 0.1838
# 24/24 [==============================] - 1s 42ms/step - loss: 0.1838 - mae: 0.1838
# 손실 함수: 0.1837652623653412 MAE: 0.1837652623653412
# LSTM 평균절댓값백분율오차(MAPE): [ 0.06706718  0.06833734 -0.00316001]
# Epoch 1/5
# 61/61 [==============================] - 14s 157ms/step - loss: 2.8881 - mae: 2.8881 - val_loss: 1.0737 - val_mae: 1.0737
# Epoch 2/5
# 61/61 [==============================] - 4s 71ms/step - loss: 0.7653 - mae: 0.7653 - val_loss: 0.8806 - val_mae: 0.8806
# Epoch 3/5
# 61/61 [==============================] - 4s 65ms/step - loss: 0.7359 - mae: 0.7359 - val_loss: 0.8295 - val_mae: 0.8295
# Epoch 4/5
# 61/61 [==============================] - 4s 64ms/step - loss: 0.7350 - mae: 0.7350 - val_loss: 0.7738 - val_mae: 0.7738
# Epoch 5/5
# 61/61 [==============================] - 4s 65ms/step - loss: 0.7185 - mae: 0.7185 - val_loss: 0.7701 - val_mae: 0.7701
# 24/24 [==============================] - 3s 69ms/step - loss: 0.7701 - mae: 0.7701
# 손실 함수: 0.7701025605201721 MAE: 0.7701025605201721
# LSTM 평균절댓값백분율오차(MAPE): [ 3.72440847e-01  4.01685218e-02 -7.28238424e-05]
# Epoch 1/5
# 61/61 [==============================] - 15s 157ms/step - loss: 2.7894 - mae: 2.7894 - val_loss: 1.5336 - val_mae: 1.5336
# Epoch 2/5
# 61/61 [==============================] - 4s 70ms/step - loss: 0.5993 - mae: 0.5993 - val_loss: 1.4517 - val_mae: 1.4517
# Epoch 3/5
# 61/61 [==============================] - 4s 68ms/step - loss: 0.5724 - mae: 0.5724 - val_loss: 1.5226 - val_mae: 1.5226
# Epoch 4/5
# 61/61 [==============================] - 4s 64ms/step - loss: 0.5723 - mae: 0.5723 - val_loss: 1.5843 - val_mae: 1.5843
# Epoch 5/5
# 61/61 [==============================] - 4s 65ms/step - loss: 0.5721 - mae: 0.5721 - val_loss: 1.4070 - val_mae: 1.4070
# 24/24 [==============================] - 3s 71ms/step - loss: 1.4070 - mae: 1.4070
# 손실 함수: 1.4070414304733276 MAE: 1.4070414304733276
# LSTM 평균절댓값백분율오차(MAPE): [ 0.51089758  0.17805601 -0.00055192]

# %%
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, LSTM, Dropout

# split = int(len(X)*0.7)
# x_train = X[0:split]; y_train=Y[0:split]
# x_test = X[split:]; y_test=Y[split:]

# model = Sequential()
# model.add(LSTM(units=64,input_shape=x_train[0].shape))
# model.add(Dense(3))
# model.compile(loss='mae')
# model.compile(loss='mae', optimizer='adam', metrics='mae')
# hist=model.fit(x_train,y_train,epochs=20,batch_size=1,validation_data=(x_test,y_test),verbose=2)

# ev=model.evaluate(x_test,y_test,verbose=1)
# print("손실 함수:", ev[0], "MAE:", ev[1])

# pred=model.predict(x_test)
# print("LSTM 평균절댓값백분율오차(MAPE):",sum(abs(y_test-pred)/y_test)/len(x_test))

# plt.plot(hist.history['mae'])
# plt.plot(hist.history['val_mae'])
# plt.title('Model mae')
# plt.ylabel('mae')
# plt.xlabel('Epoch')
# plt.legend(['Train','Validation'], loc='best')
# plt.grid()
# plt.show()

# %%
plt.figure(figsize=(8,8))
x_range=range(len(y_test))
plt.plot(x_range,y_test[x_range,1],color='red',linestyle='dotted')
plt.plot(x_range,pred[x_range,1],color='green',linestyle='dashed')
plt.legend(['True value','Predicted value'], loc='best')
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-0a1104e185a6> in <module>
#       1 plt.figure(figsize=(8,8))
# ----> 2 x_range=range(len(y_test))
#       3 plt.plot(x_range,y_test[x_range,1],color='red',linestyle='dotted')
#       4 plt.plot(x_range,pred[x_range,1],color='green',linestyle='dashed')
#       5 plt.legend(['True value','Predicted value'], loc='best')
#
# NameError: name 'y_test' is not defined

# %%
plt.plot(pred[:,1])
